# %% [markdown]
# # Assignment Week 2
#
# * Answer each question completely.
# * Include your code and summarize what you see in a brief narrative.
#
# __Charting:__
# Remember to make your charts as self-sufficient as possible (i.e., labels, titles, lack of clutter)

# %%
#printing the dataset to see number of rows and columns and names of all columns.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_data/master/ds602/car_prices/car_prices.csv', low_memory=False)

df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca         5   16639.0   white
# ...

# %%
#info() used to see the datatype of each column of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493484 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547043 non-null  object
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558837 non-null  object
#  14  sellingprice  558837 non-null  int64
#  15  saledate      558837 non-null  object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 68.2+ MB

# %% [markdown]
# # Data Description:
# - year: year the car was built (e.g., the model year)
# - make: the manufacturer.
# - model: specific model of the car
# - trim: subtype of the car model.
# - body: body style of the car.
# - transmission: type of transmission
# - state: state car is registered.
# - condition: numerical rating of the condition, higher is better.
# - odometer: number of miles the car has been driven.
# - color: color of the car.
# - interior: type of interior (e.g., seats).
# - mmr: estimated wholesale price of the car if auctioned.
# - sellingprice: actual sales price of the car.

# %% [markdown]
# ## Question 1. Determine the number of missing values in each column.

# %%
#ISNULL() shows the boolean dataframe of NAN values
df.isnull()
# Out:
#          year   make  model   trim   body  transmission    vin  state  \
# 0       False  False  False  False  False         False  False  False
# 1       False  False  False  False  False         False  False  False
# 2       False  False  False  False  False         False  False  False
# 3       False  False  False  False  False         False  False  False
# 4       False  False  False  False  False         False  False  False
# ...       ...    ...    ...    ...    ...           ...    ...    ...
# 558832  False  False  False  False  False          True  False  False
# 558833  False  False  False  False  False         False  False  False
# 558834  False  False  False  False  False         False  False  False
# 558835  False  False  False  False  False         False  False  False
# 558836  False  False  False  False  False         False  False  False
#
#         condition  odometer  color  interior  seller    mmr  sellingprice  \
# ...

# %%
#sum() counts the total NaN values at each column in a DataFrame
df.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65353
# vin                 4
# state               0
# condition       11794
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                 0
# sellingprice        0
# saledate            0
# dtype: int64

# %% [markdown]
# Sample narrative description.

# %% [markdown]
# ## Question 2. Check the data types.
# - Which columns are coded to the incorrect type? If any, correct them.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493484 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547043 non-null  object
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558837 non-null  object
#  14  sellingprice  558837 non-null  int64
#  15  saledate      558837 non-null  object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 68.2+ MB

# %%
#.unique() used to see number of unique values in column "mmr"
df['mmr'].unique()
# Out:
# array(['20500', '20800', '31900', ..., 'mid city mcandrew motors',
#        '119000', '164000'], dtype=object)

# %%
#found a string in "mmr" column. so , replaced it with "0"
df['mmr']=df['mmr'].replace('mid city mcandrew motors','0')

# %%
df['mmr'].unique()
# Out:
# array(['20500', '20800', '31900', ..., '0', '119000', '164000'],
#       dtype=object)

# %%
#created a new "MMR" column which is of datatype "float64". "mmr" has "object" datatype values. So, just coverted it to float
df['MMR'] = pd.to_numeric(df['mmr'], errors='coerce')
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca         5   16639.0   white
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493484 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547043 non-null  object
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558837 non-null  object
#  14  sellingprice  558837 non-null  int64
#  15  saledate      558837 non-null  object
#  16  MMR           558812 non-null  float64
# ...

# %% [markdown]
# Sample narrative description.

# %% [markdown]
# ## Question 3. Analyze the `make` column.
# - Comment on what you observe.
# - Clean the column to reduce the number of unique values to as few as reasonably possible (no hard coding).
#
# Hint: What do you notice if you run this:
# ```python
# makes = df.make.unique().tolist()
# makes = [str(x).lower() for x in makes]
# sorted(makes)
# ```

# %%
makes = df.make.unique()
makes
# Out:
# array(['Kia', 'BMW', 'Volvo', 'Nissan', 'Chevrolet', 'Audi', 'Ford',
#        'Hyundai', 'Buick', 'Cadillac', 'Acura', 'Lexus', 'Infiniti',
#        'Jeep', 'Mercedes-Benz', 'Mitsubishi', 'Mazda', 'MINI',
#        'Land Rover', 'Lincoln', 'lincoln', 'Jaguar', 'Volkswagen',
#        'Toyota', 'Subaru', 'Scion', 'Porsche', nan, 'bmw', 'Dodge',
#        'FIAT', 'Chrysler', 'ford', 'Ferrari', 'Honda', 'GMC',
#        'mitsubishi', 'Ram', 'smart', 'chevrolet', 'Bentley', 'chrysler',
#        'pontiac', 'Pontiac', 'Saturn', 'Maserati', 'Mercury', 'HUMMER',
#        'landrover', 'cadillac', 'land rover', 'mercedes', 'mazda',
#        'toyota', 'lexus', 'gmc truck', 'honda', 'nissan', 'porsche',
#        'Saab', 'Suzuki', 'dodge', 'subaru', 'Oldsmobile', 'oldsmobile',
#        'hyundai', 'jeep', 'Isuzu', 'dodge tk', 'Geo', 'acura',
#        'volkswagen', 'suzuki', 'kia', 'audi', 'Rolls-Royce', 'gmc',
#        'maserati', 'mazda tk', 'mercury', 'buick', 'hyundai tk',
# ...

# %%
#After running the above code, I observed that make column has duplicate names,
#but of different cases(upper case and lower cases)
makes = df.make.unique()
makes = [str(x).lower() for x in makes]
print(len(makes))
sorted(makes)
# Out:
# 97
# ['acura',
#  'acura',
#  'airstream',
#  'aston martin',
#  'audi',
#  'audi',
#  'bentley',
#  'bmw',
#  'bmw',
#  'buick',
#  'buick',
#  'cadillac',
#  'cadillac',
#  'chev truck',
#  'chevrolet',
#  'chevrolet',
#  'chrysler',
#  'chrysler',
#  'daewoo',
#  'dodge',
#  'dodge',
#  'dodge tk',
#  'dot',
#  'ferrari',
#  'fiat',
#  'fisker',
#  'ford',
#  'ford',
#  'ford tk',
#  'ford truck',
#  'geo',
#  'gmc',
#  'gmc',
#  'gmc truck',
#  'honda',
#  'honda',
#  'hummer',
#  'hyundai',
#  'hyundai',
#  'hyundai tk',
#  'infiniti',
#  'isuzu',
#  'jaguar',
#  'jeep',
#  'jeep',
#  'kia',
#  'kia',
#  'lamborghini',
#  'land rover',
#  'land rover',
#  'landrover',
#  'lexus',
#  'lexus',
#  'lincoln',
#  'lincoln',
#  'lotus',
#  'maserati',
#  'maserati',
#  'mazda',
#  'mazda',
#  'mazda tk',
#  'mercedes',
#  'mercedes-b',
#  'mercedes-benz',
#  'mercury',
#  'mercury',
#  'mini',
#  'mitsubishi',
#  'mitsubishi',
#  'nan',
#  'nissan',
#  'nissan',
#  'oldsmobile',
# ...

# %%
#created a new column "MAKE" which is a cleaned version of "make" column where all names are converted to lower case. 
df['MAKE']=[str(x).lower() for x in df['make']]
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca         5   16639.0   white
# ...

# %%
#checked whether all names are converted to lower case or not.
df['MAKE'].unique()
# Out:
# array(['kia', 'bmw', 'volvo', 'nissan', 'chevrolet', 'audi', 'ford',
#        'hyundai', 'buick', 'cadillac', 'acura', 'lexus', 'infiniti',
#        'jeep', 'mercedes-benz', 'mitsubishi', 'mazda', 'mini',
#        'land rover', 'lincoln', 'jaguar', 'volkswagen', 'toyota',
#        'subaru', 'scion', 'porsche', 'nan', 'dodge', 'fiat', 'chrysler',
#        'ferrari', 'honda', 'gmc', 'ram', 'smart', 'bentley', 'pontiac',
#        'saturn', 'maserati', 'mercury', 'hummer', 'landrover', 'mercedes',
#        'gmc truck', 'saab', 'suzuki', 'oldsmobile', 'isuzu', 'dodge tk',
#        'geo', 'rolls-royce', 'mazda tk', 'hyundai tk', 'mercedes-b', 'vw',
#        'daewoo', 'chev truck', 'ford tk', 'plymouth', 'ford truck',
#        'tesla', 'airstream', 'dot', 'aston martin', 'fisker',
#        'lamborghini', 'lotus'], dtype=object)

# %%
#after cleaning, 97 unique names in "make" column are reduced to 67 unique names 
df['MAKE'].nunique()
# Out:
# 67

# %%
final = []
[final.append(x) for x in makes if x not in final]
print(len(final))
print(str(final))
# Out:
# 67
# ['kia', 'bmw', 'volvo', 'nissan', 'chevrolet', 'audi', 'ford', 'hyundai', 'buick', 'cadillac', 'acura', 'lexus', 'infiniti', 'jeep', 'mercedes-benz', 'mitsubishi', 'mazda', 'mini', 'land rover', 'lincoln', 'jaguar', 'volkswagen', 'toyota', 'subaru', 'scion', 'porsche', 'nan', 'dodge', 'fiat', 'chrysler', 'ferrari', 'honda', 'gmc', 'ram', 'smart', 'bentley', 'pontiac', 'saturn', 'maserati', 'mercury', 'hummer', 'landrover', 'mercedes', 'gmc truck', 'saab', 'suzuki', 'oldsmobile', 'isuzu', 'dodge tk', 'geo', 'rolls-royce', 'mazda tk', 'hyundai tk', 'mercedes-b', 'vw', 'daewoo', 'chev truck', 'ford tk', 'plymouth', 'ford truck', 'tesla', 'airstream', 'dot', 'aston martin', 'fisker', 'lamborghini', 'lotus']

# %% [markdown]
# Sample narrative description.

# %% [markdown]
# ## Question 4. Analyze the relationship between the wholeprice `mmr` and the `salesprice`.
# - What is the overall correlation?
# - What happens to the correlation as you increase the maximum selling price window (e.g., 0-10000, 0-20000,...)?
# - Create a scatter plot with the relationship.
# - Create a graph that shows how the correlation changes.

# %%
#overall correlation 
print(df['MMR'].corr(df['sellingprice']))
print(df['MMR'].corr(df['sellingprice'][(df['sellingprice'] >=0) & (df['sellingprice'] < 10000)]))
# Out:
# 0.9836319908100759
# 0.8710246568086276

# %%
#overall correlation
df[['MMR','sellingprice']].corr()
# Out:
#                    MMR  sellingprice
# MMR           1.000000      0.983632
# sellingprice  0.983632      1.000000

# %%
#scatterplot with the relation of "MMR" and "sellingprice"
df[['MMR','sellingprice']].plot.scatter(x='sellingprice', y='MMR', alpha=.1)
plt.xlabel('sellingprice')
plt.ylabel('MMR')
plt.show()

# %%
df['sellingprice'].max()
# Out:
# 230000

# %%
df['sellingprice'].max()

lis=[]
lis2=[]
for i in range(0,230000,10000):
    
    lis.append(df['MMR'].corr(df['sellingprice'][(df['sellingprice'] >=0) & (df['sellingprice'] < i)]))
    lis2.append(df['MMR'][(df['sellingprice'] >=0) & (df['sellingprice'] < i)].mean())
    
lis
lis2

plt.plot(lis2,lis)

# %% [markdown]
# Sample narrative description.

# %% [markdown]
# ## Question 5. How does the distribution of `salesprice` vary by make for cars made between 2010-2015?
# - Use the 10 most common makes (your cleaned version of this column).
# - Create a graph that answers this question.

# %%
#used the clean version of MAKE column and used the 10 most common makes.
meanNflPivot = df[df['year'] > 2009].pivot_table(index='MAKE', columns='year', values='sellingprice', aggfunc='count')
meanNflPivot.dropna(inplace=True)
meanNflPivot['count'] = meanNflPivot.sum(axis=1)
meanNflPivot.sort_values('count', ascending=False, inplace=True)
meanNflPivot[:10]
# Out:
# year         2010    2011     2012     2013     2014    2015    count
# MAKE
# ford       4150.0  7745.0  15851.0  22332.0  19497.0   990.0  70565.0
# nissan     1576.0  5917.0  16879.0  11727.0   5652.0   623.0  42374.0
# chevrolet  3677.0  5414.0   7379.0  10904.0   9349.0  1438.0  38161.0
# toyota     2137.0  4140.0   7230.0   6706.0   5813.0   237.0  26263.0
# dodge      2643.0  1604.0   2970.0   5855.0   6851.0   246.0  20169.0
# hyundai     878.0  1674.0   4378.0   7882.0   2583.0   504.0  17899.0
# honda      1402.0  1738.0   8684.0   2537.0   1206.0    77.0  15644.0
# kia         719.0  1340.0   2589.0   3044.0   6173.0  1482.0  15347.0
# infiniti    151.0  2849.0   4464.0   4244.0   1002.0    10.0  12720.0
# bmw         632.0  2739.0   4383.0   1797.0   1696.0   658.0  11905.0

# %%
import seaborn as sns

plt.figure(figsize=(9, 9))
sns.heatmap(meanNflPivot[:10], annot=True, fmt='.1f')
plt.xlabel('')
plt.ylabel('')
plt.title('distribution')
plt.show()

# %% [markdown]
# Sample narrative description.
